# %%
import re
import pandas as pd
import numpy as np

# %% [markdown]
# ## Cleaning up clinical data table

# %%
master_dir = ''
df = pd.read_csv(master_dir + "data/validation_metabolites/observations_2020-09-04_1027.tsv", sep='\t')
df.head()
# Out:
#   source_label                        observation_id  \
# 0     INCOV001  d79653c2-9fd2-42d4-bc55-389c3a195199
# 1     INCOV001  0136c6b6-5c01-42ca-a1ea-d1286f193041
# 2     INCOV001  d372353b-edf7-4d01-adc9-567603c30bc7
# 3     INCOV001  0c738d29-36ec-4de2-8c0a-b0e4fa76ebd2
# 4     INCOV002  febb8188-16ae-48e5-8a73-e711dd811856
#
#     incov_redcap_event_name  observation_days_since_enrollment abdominal_pain  \
# 0          admittance_arm_1                              -8.42             No
# 1  baseline_blood_dra_arm_1                               0.92             No
# 2    acute_blood_draw_arm_1                               5.92             No
# 3  convalescent_blood_arm_1                             105.21        Unknown
# 4          admittance_arm_1                              -1.04             No
#
#                  ambulatory blood_draw_status blood_draw_status_bad  \
# 0  Limitation of activities               NaN                   NaN
# 1  Limitation of activities          Complete                   NaN
# 2  Limitation of activities          Complete                   NaN
# 3                       NaN          Complete                   NaN
# 4  Limitation of activities               NaN                   NaN
#
#   blood_draw_type  blood_oxygenation  ...  pulse  respiratory_rate  \
# 0             NaN               96.0  ...   69.0              20.0
# 1        Baseline               95.0  ...   55.0              22.0
# 2           Acute               96.0  ...   66.0              18.0
# 3    Convalescent                NaN  ...    NaN               NaN
# 4             NaN               94.0  ...   97.0              20.0
#
#   respiratory_support sputum systolic_bp  temperature temperature_max  \
# 0                None     No       138.0         36.8            37.1
# 1                None     No       139.0         36.6            36.6
# 2                None     No       140.0         36.3            36.6
# 3                None    NaN         NaN          NaN             NaN
# 4       Nasal cannula     No       137.0         37.8            38.5
#
#   temperature_min weight who_ordinal_scale
# 0            36.8   97.5                 3
# 1            36.4   97.5                 3
# 2            36.3   97.5                 3
# 3             NaN    NaN               <=2
# 4            37.2   90.7                 4
#
# [5 rows x 36 columns]

# %%
df['incov_redcap_event_name'].unique()
# Out:
# array(['admittance_arm_1', 'baseline_blood_dra_arm_1',
#        'acute_blood_draw_arm_1', 'convalescent_blood_arm_1',
#        'physician_discreti_arm_1'], dtype=object)

# %%
# Only need to look at T1 and T2, which are the two items below respectively
df = df[df['incov_redcap_event_name'].isin(['baseline_blood_dra_arm_1', 'acute_blood_draw_arm_1'])]
df['incov_redcap_event_name'] = df['incov_redcap_event_name'].map({'baseline_blood_dra_arm_1': 'T1', 
                                                                   'acute_blood_draw_arm_1': 'T2'})

# %%
df['patient_num'] = df['source_label'].str.replace("INCOV", "").str.replace("^0+", "")

# %%
df['patient_num'] = df['patient_num'] + '-' + df['incov_redcap_event_name'].apply(lambda x: x[-1])

# %%
df.tail()
# Out:
#     source_label                        observation_id  \
# 535     INCOV162  96187e76-58a4-4bf5-afdc-014cd81b70b8
# 536     INCOV162  d75aee66-b021-4181-9601-0b390172c442
# 537     INCOV163  c51b79f1-b200-44fd-b355-3bd685c7d5ef
# 538     INCOV163  1f9d562c-22ee-459c-9353-72c7ad23a76b
# 540     INCOV165  5d2f8a85-dca3-4c2d-822e-af0130e80a08
#
#     incov_redcap_event_name  observation_days_since_enrollment abdominal_pain  \
# 535                      T1                               0.00             No
# 536                      T2                              11.12        Unknown
# 537                      T1                               0.58        Unknown
# 538                      T2                               2.58             No
# 540                      T1                               0.71             No
#
#                       ambulatory blood_draw_status blood_draw_status_bad  \
# 535     Limitation of activities          Complete                   NaN
# 536  No limitation of activities          Complete                   NaN
# 537     Limitation of activities          Complete                   NaN
# 538     Limitation of activities          Complete                   NaN
# 540                          NaN          Complete                   NaN
#
#     blood_draw_type  blood_oxygenation  ...  respiratory_rate  \
# 535        Baseline               99.0  ...              24.0
# 536           Acute                NaN  ...               NaN
# 537        Baseline               95.0  ...              16.0
# 538           Acute               95.0  ...              16.0
# 540        Baseline               99.0  ...              20.0
#
#                 respiratory_support   sputum systolic_bp temperature  \
# 535                            None  Unknown       122.0        36.7
# 536                            None  Unknown         NaN         NaN
# 537                   Nasal cannula      Yes       103.0        36.6
# 538                            None      Yes        97.0        36.4
# 540  High flow nasal cannula (HFNC)       No       100.0        36.3
#
#      temperature_max temperature_min weight who_ordinal_scale patient_num
# 535             37.2            36.4  106.5                 3       162-1
# 536              NaN             NaN    NaN                 1       162-2
# 537             36.6            36.4   82.1                 4       163-1
# 538             36.7            36.4   82.7                 3       163-2
# 540             36.9            36.3   80.0                 5       165-1
#
# [5 rows x 37 columns]

# %%
df.to_csv(master_dir + "data/observations_2020-09-04_1027-cleaned.tsv", index=False)

# %% [markdown]
# ## Cleaning up drug treatment data table

# %%
df = pd.read_csv(master_dir + 'data/validation_metabolites/drug_treatments_2020-09-04_1027.tsv', sep='\t')
df.head()
# Out:
#   source_label                        observation_id drug_treatment  \
# 0     INCOV001  4556f31a-2c98-47a3-b91d-6c83ecd306bc          vir_0
# 1     INCOV002  6ca4bf39-8c44-455d-adfa-24c781b43016          adj_0
# 2     INCOV002  6ca4bf39-8c44-455d-adfa-24c781b43016          adj_1
# 3     INCOV002  6ca4bf39-8c44-455d-adfa-24c781b43016          adj_2
# 4     INCOV002  6ca4bf39-8c44-455d-adfa-24c781b43016          adj_3
#
#      treatment_type  start_treatment_days_since_enrollment  \
# 0  Remdesivir (RDV)                                   1.67
# 1       Tocilizumab                                   0.42
# 2       Tocilizumab                                   3.00
# 3       Tocilizumab                                   3.54
# 4         Vitamin C                                  -0.12
#
#    end_treatment_days_since_enrollment
# 0                                 6.00
# 1                                 0.46
# 2                                 3.04
# 3                                 3.58
# 4                                 4.88

# %%
df['drug_treatment'].unique()
# Out:
# array(['vir_0', 'adj_0', 'adj_1', 'adj_2', 'adj_3', 'adj_4', 'vir_1',
#        'vir_2', 'adj_5'], dtype=object)

# %%
df['patient_num'] = df['source_label'].str.replace("INCOV", "").str.replace("^0+", "")

# %%
df_clinical = pd.read_csv(master_dir + "data/observations_2020-09-04_1027-cleaned.tsv")
df_clinical.head()
# Out:
#   source_label                        observation_id incov_redcap_event_name  \
# 0     INCOV001  0136c6b6-5c01-42ca-a1ea-d1286f193041                      T1
# 1     INCOV001  d372353b-edf7-4d01-adc9-567603c30bc7                      T2
# 2     INCOV002  7403b5ac-6810-431e-bc21-f39a81edbf27                      T1
# 3     INCOV002  b21d9bf4-07cf-4d0d-9638-0e02f739f989                      T2
# 4     INCOV003  04e24104-e195-4a32-85e7-bdc935800f4a                      T1
#
#    observation_days_since_enrollment abdominal_pain                ambulatory  \
# 0                               0.92             No  Limitation of activities
# 1                               5.92             No  Limitation of activities
# 2                               0.71             No  Limitation of activities
# 3                               5.75        Unknown  Limitation of activities
# 4                               0.54        Unknown  Limitation of activities
#
#   blood_draw_status blood_draw_status_bad blood_draw_type  blood_oxygenation  \
# 0          Complete                   NaN        Baseline               95.0
# 1          Complete                   NaN           Acute               96.0
# 2          Complete                   NaN        Baseline               96.0
# 3          Complete                   NaN           Acute               91.0
# 4          Complete                   NaN        Baseline               96.0
#
#    ...  respiratory_rate             respiratory_support sputum systolic_bp  \
# 0  ...              22.0                            None     No       139.0
# 1  ...              18.0                            None     No       140.0
# 2  ...              20.0  High flow nasal cannula (HFNC)    Yes        96.0
# 3  ...              20.0                           Other     No       125.0
# 4  ...              21.0                           Other    Yes        89.0
#
#   temperature  temperature_max temperature_min weight who_ordinal_scale  \
# 0        36.6             36.6            36.4   97.5                 3
# 1        36.3             36.6            36.3   97.5                 3
# 2        37.3             38.5            36.3   90.7                 5
# 3        36.8             36.8            36.4   94.8                 7
# 4        37.2             37.2            36.7   77.6                 7
#
#   patient_num
# 0         1-1
# 1         1-2
# 2         2-1
# 3         2-2
# 4         3-1
#
# [5 rows x 37 columns]

# %%
df['treatment_type'].unique()
# Out:
# array(['Remdesivir (RDV)', 'Tocilizumab', 'Vitamin C', 'Zinc',
#        'Hydroxychloroquine (HCQ)', 'HCQ + Azithromycin', 'Steroid',
#        'Other', 'Plasma Transfusions'], dtype=object)

# %%
df[df['treatment_type']=='Remdesivir (RDV)']
# Out:
#     source_label                        observation_id drug_treatment  \
# 0       INCOV001  4556f31a-2c98-47a3-b91d-6c83ecd306bc          vir_0
# 7       INCOV002  e64110e8-ef0a-40ca-a668-b29895e878e1          vir_1
# 9       INCOV003  5ca162aa-bf11-4fd9-9b9f-a2f56a4d0dd8          vir_1
# 13      INCOV004  b3899e45-3ad7-4b5b-b727-f54256df3eb0          vir_0
# 14      INCOV005  c6bf24de-b963-4cb7-ac9f-9467239573d2          vir_0
# 21      INCOV006  456b2bac-b5c7-4449-bba3-a6ef38f36f10          vir_0
# 24      INCOV007  7d265e46-9aba-42c6-81d4-b10b220931b2          vir_0
# 31      INCOV009  4084c9e0-9d73-4280-9c23-7ef773664c1b          vir_0
# 34      INCOV012  d299b7bd-675d-4606-9db0-d48f4c7d8592          vir_0
# 37      INCOV013  0fc445ff-776d-4662-bc30-79a3e4dcbe8c          vir_2
# 41      INCOV014  c380f8f1-756f-4552-9292-1ed3cbba6d43          vir_0
# 43      INCOV015  0924a9aa-0ea5-40a5-8015-b913bcb2ce80          vir_0
# 47      INCOV016  85b15ea1-b5bc-4898-b3e1-453428303e92          vir_0
# 48      INCOV017  14717d1d-37af-4dd2-b246-5fb2fe5ecc62          vir_0
# 55      INCOV018  889addeb-b07d-4194-ab92-813a4f7a8404          vir_2
# 64      INCOV023  f0dbeaa3-bb1e-4ee9-86f1-efc3f21801ac          vir_0
# 70      INCOV026  55f3f57a-977c-4a77-9663-df3216bb4fd2          vir_0
# 0                        T1                               0.92             No
# 1                        T2                               5.92             No
# 2                        T1                               0.71             No
# 3                        T2                               5.75        Unknown
# 4                        T1                               0.54        Unknown
# ..                      ...                                ...            ...
# 296                      T1                               0.00             No
# 297                      T2                              11.12        Unknown
# 298                      T1                               0.58        Unknown
# 299                      T2                               2.58             No
# 300                      T1                               0.71             No
#
#                       ambulatory blood_draw_status blood_draw_status_bad  \
# 0       Limitation of activities          Complete                   NaN
# 1       Limitation of activities          Complete                   NaN
# 2       Limitation of activities          Complete                   NaN
# 3       Limitation of activities          Complete                   NaN
# 4       Limitation of activities          Complete                   NaN
# ..                           ...               ...                   ...
# 296     Limitation of activities          Complete                   NaN
# 297  No limitation of activities          Complete                   NaN
# 298     Limitation of activities          Complete                   NaN
# 299     Limitation of activities          Complete                   NaN
# 300                          NaN          Complete                   NaN
#
#     blood_draw_type  blood_oxygenation  ...  patient_num  \
# 0          Baseline               95.0  ...          1-1
# 1             Acute               96.0  ...          1-2
# 2          Baseline               96.0  ...          2-1
# 3             Acute               91.0  ...          2-2
# 4          Baseline               96.0  ...          3-1
# ..              ...                ...  ...          ...
# 296        Baseline               99.0  ...        162-1
# 297           Acute                NaN  ...        162-2
# 298        Baseline               95.0  ...        163-1
# 299           Acute               95.0  ...        163-2
# 300        Baseline               99.0  ...        165-1
#
#      time_wrt_Remdesivir (RDV) time_wrt_Tocilizumab time_wrt_Vitamin C  \
# 0                       Before                No.T1              No.T1
# 1                        After                No.T2              No.T2
# 2                       Before                After             Before
# 3                        After                After              After
# 4                       Before               Before             Before
# ..                         ...                  ...                ...
# 296                      No.T1                No.T1              No.T1
# 297                      No.T2                No.T2              No.T2
# 298                      No.T1                No.T1              No.T1
# 299                      No.T2                No.T2              No.T2
# 300                      No.T1                No.T1              No.T1
#
#     time_wrt_Zinc  time_wrt_Hydroxychloroquine (HCQ)  \
# 0           No.T1                              No.T1
# 1           No.T2                              No.T2
# 2          Before                              After
# 3          Before                              After
# 4           No.T1                              After
# ..            ...                                ...
# 296         No.T1                              No.T1
# 297         No.T2                              No.T2
# 298         No.T1                              No.T1
# 299         No.T2                              No.T2
# 300         No.T1                              No.T1
#
#     time_wrt_HCQ + Azithromycin time_wrt_Steroid time_wrt_Other  \
# 0                         No.T1            No.T1          No.T1
# 1                         No.T2            No.T2          No.T2
# 2                         No.T1            No.T1          No.T1
# 3                         No.T2            No.T2          No.T2
# 4                         No.T1            No.T1          No.T1
# ..                          ...              ...            ...
# 296                       No.T1            No.T1          No.T1
# 297                       No.T2            No.T2          No.T2
# 298                       No.T1            No.T1          No.T1
# 299                       No.T2            No.T2          No.T2
# 300                       No.T1            No.T1          No.T1
#
#     time_wrt_Plasma Transfusions
# 0                          No.T1
# 1                          No.T2
# 2                          No.T1
# 3                          No.T2
# 4                          No.T1
# ..                           ...
# 296                        No.T1
# 297                        No.T2
# 298                        No.T1
# 299                        No.T2
# 300                        No.T1
#
# [301 rows x 46 columns]

# %%
# Determine whether the treatment was before or after each timepoint
# Compare df_clinical observation_days_since_enrollment vs. start_treatment_days_since_enrollment
# Do this per drug treatment
for tx in df['treatment_type'].unique():
    colname = 'time_wrt_' + tx
    df_clinical[colname] = pd.Series()
    for obs in df_clinical.index:
        clin = df_clinical.loc[obs]
        source = clin['source_label']
        try:
            temp = df[df['treatment_type']==tx][df['source_label']==source].iloc[0]
            
            # If patient received any of this treatment, take the T1 and T2 as already defined
            if clin['incov_redcap_event_name']=='T1':
                df_clinical.loc[obs, colname] = 'Before'
            elif clin['incov_redcap_event_name']=='T2':
                df_clinical.loc[obs, colname] = 'After'
                
        except:
            df_clinical.loc[obs, colname] = 'No.T' + clin['patient_num'][-1]
            
df_clinical.head()
# Out:
# <ipython-input-24-f66d00816944>:6: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_clinical[colname] = pd.Series()
# <ipython-input-24-f66d00816944>:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   temp = df[df['treatment_type']==tx][df['source_label']==source].iloc[0]
#   source_label                        observation_id incov_redcap_event_name  \
# 0     INCOV001  0136c6b6-5c01-42ca-a1ea-d1286f193041                      T1
# 1     INCOV001  d372353b-edf7-4d01-adc9-567603c30bc7                      T2
# 2     INCOV002  7403b5ac-6810-431e-bc21-f39a81edbf27                      T1
# 3     INCOV002  b21d9bf4-07cf-4d0d-9638-0e02f739f989                      T2
# 4     INCOV003  04e24104-e195-4a32-85e7-bdc935800f4a                      T1
#
#    observation_days_since_enrollment abdominal_pain                ambulatory  \
# 0                               0.92             No  Limitation of activities
# 1                               5.92             No  Limitation of activities
# 2                               0.71             No  Limitation of activities
# 3                               5.75        Unknown  Limitation of activities
# 4                               0.54        Unknown  Limitation of activities
#
#   blood_draw_status blood_draw_status_bad blood_draw_type  blood_oxygenation  \
# 0          Complete                   NaN        Baseline               95.0
# 1          Complete                   NaN           Acute               96.0
# 2          Complete                   NaN        Baseline               96.0
# 3          Complete                   NaN           Acute               91.0
# 4          Complete                   NaN        Baseline               96.0
#
#    ...  patient_num  time_wrt_Remdesivir (RDV) time_wrt_Tocilizumab  \
# 0  ...          1-1                     Before                No.T1
# 1  ...          1-2                      After                No.T2
# 2  ...          2-1                     Before               Before
# 3  ...          2-2                      After                After
# 4  ...          3-1                     Before               Before
#
#   time_wrt_Vitamin C time_wrt_Zinc  time_wrt_Hydroxychloroquine (HCQ)  \
# 0              No.T1         No.T1                              No.T1
# 1              No.T2         No.T2                              No.T2
# 2             Before        Before                             Before
# 3              After         After                              After
# 4             Before         No.T1                             Before
#
#   time_wrt_HCQ + Azithromycin time_wrt_Steroid time_wrt_Other  \
# 0                       No.T1            No.T1          No.T1
# 1                       No.T2            No.T2          No.T2
# 2                       No.T1            No.T1          No.T1
# 3                       No.T2            No.T2          No.T2
# 4                       No.T1            No.T1          No.T1
#
#   time_wrt_Plasma Transfusions
# 0                        No.T1
# 1                        No.T2
# 2                        No.T1
# 3                        No.T2
# 4                        No.T1
#
# [5 rows x 46 columns]

# %%
sum(df_clinical['time_wrt_Remdesivir (RDV)'].isin(['No.T1', 'No.T2', 'After']))
# Out:
# 250

# %%
sum(df_clinical['time_wrt_Remdesivir (RDV)']=='Before')
# Out:
# 51

# %%
sum(df_clinical['time_wrt_Remdesivir (RDV)']=='After')
# Out:
# 45

# %%
df.to_csv(master_dir + 'data/drug_treatments_2020-09-04_1027-cleaned.tsv', index=False)
df_clinical.to_csv(master_dir + "data/observations_2020-09-04_1027-cleaned-withTxInfo.tsv", index=False)
